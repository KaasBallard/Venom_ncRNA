# %% [markdown]
# Step 1
# Date: 2024/12/19
# The purpose of this script is to take the GFF created by gffread with the following command:
#
# gffread -E /home/administrator/Documents/Kaas/Venom_ncRNA_project/Usable_data/Genome_files/CroVir_rnd1.all.maker.final.homologIDs.updatedNov2019_with_myos_geneidmod_edited_with_BPP.gtf -o /home/administrator/Documents/Kaas/Venom_ncRNA_project/Usable_data/Genome_files/Crotalus_viridis_annotation_with_BPP_and_myotoxin_2024.12.18.gff
#
# and fix re-add the three_prime_utr and five_prime_utr sequences back.
#
# Next step: BCFtools_get_fasta_file_three_prime_utr_2024.12.20.sh (/home/administrator/Documents/Kaas/Venom_ncRNA_project/Scripts/BCFtools/BCFtools_get_fasta_file_three_prime_utr_2024.12.20.sh)
# Previous step: None

# %%
# Import needed packages
import pandas as pd
import polars as pl
import os

# %%
# Laod file path into memory
gtf = '/home/administrator/Documents/Kaas/Venom_ncRNA_project/Usable_data/Genome_files/CroVir_rnd1.all.maker.final.homologIDs.updatedNov2019_with_myos_geneidmod_edited_with_BPP.gtf'

# Load GTF into memory
gtf_df = pd.read_csv(
    gtf, sep = '\t', comment = '#', header = None, names= [
        'seqid', 'source', 'type2', 'start', 'end', 'score', 'strand', 'phase', 'attributes2'
    ]
)

# Laod the file path of the GFF into memory
gff = '/home/administrator/Documents/Kaas/Venom_ncRNA_project/Usable_data/Genome_files/Crotalus_viridis_annotation_with_BPP_and_myotoxin_2024.12.18.gff'

# Load the GFF into memory
gff_df = pd.read_csv(
    gff, sep='\t', comment='#', header=None, names = [
        'seqid', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase', 'attributes'
    ]
)

# %%
# Get common columns for the two data frames
shared_cols = gff_df.columns.intersection(gtf_df.columns).tolist()
print(shared_cols)
# Out:
# ['seqid', 'source', 'start', 'end', 'score', 'strand', 'phase']

# %%
# Join the data frames and filter out any removing everthing unneaded from the GFF section
gxf_df = (pd.merge(
    gff_df, gtf_df,
    on = shared_cols,
    how = 'outer'
)
)
gxf_df
# Out:
#                            seqid source        type  start   end score strand  \
# 0       PE-reconstructed-10x-myo      .  transcript      1  2076     .      +
# 1       PE-reconstructed-10x-myo      .  transcript      1  2076     .      +
# 2       PE-reconstructed-10x-myo      .        exon      1   746     .      +
# 3       PE-reconstructed-10x-myo      .        exon   1640  1765     .      +
# 4       PE-reconstructed-10x-myo      .        exon   1911  2076     .      +
# ...                          ...    ...         ...    ...   ...   ...    ...
# 372379            scaffold-un945  maker         NaN   3236  3291     .      +
# 372380           scaffold-un1500  maker         NaN    778   780     .      -
# 372381           scaffold-un2620  maker         NaN    307   837     .      -
# 372382           scaffold-un3951  maker         NaN   1109  1281     .      -
# 372383           scaffold-un3951  maker         NaN     30    63     .      -
#
#        phase                            attributes            type2  \
# 0          .  ID=myotoxin_model_1;geneID=myotoxin1             gene
# 1          .  ID=myotoxin_model_1;geneID=myotoxin1       transcript
# 2          .               Parent=myotoxin_model_1             exon
# 3          .               Parent=myotoxin_model_1             exon
# 4          .               Parent=myotoxin_model_1             exon
# ...      ...                                   ...              ...
# 372379     .                                   NaN  three_prime_utr
# 372380     .                                   NaN  three_prime_utr
# 372381     .                                   NaN  three_prime_utr
# 372382     .                                   NaN   five_prime_utr
# 372383     .                                   NaN  three_prime_utr
#
#                                               attributes2
# 0       gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 1       gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 2       gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 3       gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 4       gene_id "myotoxin1"; transcript_id "myotoxin_m...
# ...                                                   ...
# 372379  gene_id "maker-scaffold-un945-augustus-gene-0....
# 372380  gene_id "augustus_masked-scaffold-un1500-proce...
# 372381  gene_id "maker-scaffold-un2620-augustus-gene-0...
# 372382  gene_id "maker-scaffold-un3951-augustus-gene-0...
# 372383  gene_id "maker-scaffold-un3951-augustus-gene-0...
#
# [372384 rows x 11 columns]

# %%
# Fix the ranges for the three_prime_utr and five_prime_utr and get proper feature values into the type column so that 3' and 5' UTRs aren't missing anymore
gxf_df2 = (
    gxf_df
        .query('type2 != "gene"') # Filter out instances of gene IDs in that row to reduce data complexity
        # Copy they three_prime_utr and five_prime_utrs into the main type column
        # .assign(
        #     type = lambda x: x['type2'].where(x['type2'].isin(['three_prime_utr', 'five_prime_utr']), x['type'])
        # )
        # .drop(columns = ['type2', 'attributes2']) # Remove columns I don't need
        .drop_duplicates() # Equivalent to distinct() in R
        # Add a new column to clarify what genes are what
        .assign(
            gene_id = lambda x: x['attributes2'].str.extract(r'gene_id "([^"]+)"')
        )
)
gxf_df2

# Create a dictionary to map gene_id to attributes where type2 is 'exon'
exon_attributes = gxf_df2[gxf_df2['type2'] == 'exon'].set_index('gene_id')['attributes'].to_dict()

# Replace missing values in 'attributes' for 'three_prime_utr' or 'five_prime_utr' rows when 'type2' is 'exon'
gxf_df2['attributes'] = gxf_df2.apply(
    lambda row: exon_attributes.get(row['gene_id'], row['attributes']) if pd.isna(row['attributes']) else row['attributes'],
    axis=1
)

# %%
gxf_df2
# Out:
#                            seqid source        type  start   end score strand  \
# 1       PE-reconstructed-10x-myo      .  transcript      1  2076     .      +
# 2       PE-reconstructed-10x-myo      .        exon      1   746     .      +
# 3       PE-reconstructed-10x-myo      .        exon   1640  1765     .      +
# 4       PE-reconstructed-10x-myo      .        exon   1911  2076     .      +
# 6                     scaffold-Z  maker  transcript   5240  9278     .      -
# ...                          ...    ...         ...    ...   ...   ...    ...
# 372379            scaffold-un945  maker         NaN   3236  3291     .      +
# 372380           scaffold-un1500  maker         NaN    778   780     .      -
# 372381           scaffold-un2620  maker         NaN    307   837     .      -
# 372382           scaffold-un3951  maker         NaN   1109  1281     .      -
# 372383           scaffold-un3951  maker         NaN     30    63     .      -
#
#        phase                                         attributes  \
# 1          .               ID=myotoxin_model_1;geneID=myotoxin1
# 2          .                            Parent=myotoxin_model_1
# 3          .                            Parent=myotoxin_model_1
# 4          .                            Parent=myotoxin_model_1
# 6          .  ID=maker-scaffold-Z-augustus-gene-0.12-mRNA-1;...
# ...      ...                                                ...
# 372379     .  Parent=maker-scaffold-un945-augustus-gene-0.1-...
# 372380     .  Parent=augustus_masked-scaffold-un1500-process...
# 372381     .  Parent=maker-scaffold-un2620-augustus-gene-0.1...
# 372382     .  Parent=maker-scaffold-un3951-augustus-gene-0.1...
# 372383     .  Parent=maker-scaffold-un3951-augustus-gene-0.1...
#
#                   type2                                        attributes2  \
# 1            transcript  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 2                  exon  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 3                  exon  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 4                  exon  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 6            transcript  gene_id "maker-scaffold-Z-augustus-gene-0.12_c...
# ...                 ...                                                ...
# 372379  three_prime_utr  gene_id "maker-scaffold-un945-augustus-gene-0....
# 372380  three_prime_utr  gene_id "augustus_masked-scaffold-un1500-proce...
# 372381  three_prime_utr  gene_id "maker-scaffold-un2620-augustus-gene-0...
# 372382   five_prime_utr  gene_id "maker-scaffold-un3951-augustus-gene-0...
# 372383  three_prime_utr  gene_id "maker-scaffold-un3951-augustus-gene-0...
#
#                                                   gene_id
# 1                                               myotoxin1
# 2                                               myotoxin1
# 3                                               myotoxin1
# 4                                               myotoxin1
# 6       maker-scaffold-Z-augustus-gene-0.12_crovir-tra...
# ...                                                   ...
# 372379             maker-scaffold-un945-augustus-gene-0.1
# 372380  augustus_masked-scaffold-un1500-processed-gene...
# 372381            maker-scaffold-un2620-augustus-gene-0.1
# 372382            maker-scaffold-un3951-augustus-gene-0.1
# 372383            maker-scaffold-un3951-augustus-gene-0.1
#
# [352107 rows x 12 columns]

# %%
# Define a function that takes a data frame and re-calculates ranges for the exon
def range_recalc(df1, df2):

    # Iterate through rows, checking if the data ranges overlap
    # df1 is the exon df
    for i, rows1 in df1.iterrows():

        # df2 is the 3'UTR df
        for j, rows2 in df2.iterrows():
            
            # Check if the row is a three_prime_utr row, and if so do this stuff:
            if rows2['type2'] == 'three_prime_utr':

                # Check if the sequence IDs are the same and only continue if true
                if (
                    rows1['seqid'] == rows2['seqid'] 
                    and rows1['type'] == 'exon' 
                    and rows1['gene_id'] == rows2['gene_id']
                    and rows1['source'] == rows2['source']
                ):

                    print(f"Matching seqid found: {rows1['seqid']}")

                    # Check if what strand the sequence is on
                    # If the strand is sense do that
                    if rows1['strand'] == '+':
                        # Check if the ranges overlap
                        if rows1['start'] < rows2['start'] and rows1['end'] == rows2['end']:
                            # Adjust the end point for row1 (the exon)
                            df1.at[i, 'end'] = rows2['start'] - 1
                            print(f"Adjusted end for row {i}: {df1.at[i, 'end']}")
                        else:
                            print(f"Ranges do not overlap for row {i}")
                            continue

                    # If the strand is anti-sense do this
                    elif rows1['strand'] == '-':
                        # Check if the ranges overlap
                        if rows1['start'] == rows2['start'] and rows1['end'] > rows2['end']:
                            # Adjust the start point for row1 (the exon)
                            df1.at[i, 'start'] = rows2['end'] + 1 
                            print(f"Adjusted start for row {i}: {df1.at[i, 'start']}")
                        else:
                            print(f"Ranges do not overlap for row {i}")
                            continue 
                    else:
                        continue
                else:
                    continue


            # Check if the row is a five_prime_utr row, and if so do this stuff:        
            elif rows2['type2'] == 'five_prime_utr':

                # Check if the sequence IDs are the same and only continue if true
                if (
                    rows1['seqid'] == rows2['seqid'] 
                    and rows1['type'] == 'exon' 
                    and rows1['gene_id'] == rows2['gene_id']
                    and rows1['source'] == rows2['source']
                ):

                    print(f"Matching seqid found: {rows1['seqid']}")

                    # Check if what strand the sequence is on
                    # If the strand is sense do that
                    if rows1['strand'] == '+':
                        # Check if the ranges overlap
                        if rows1['start'] == rows2['start'] and rows1['end'] > rows2['end']:
                            # Adjust the start point for row1 (the exon)
                            df1.at[i, 'start'] = rows2['end'] + 1 
                            print(f"Adjusted start for row {i}: {df1.at[i, 'start']}")
                        else:
                            print(f"Ranges do not overlap for row {i}")
                            continue 
                    
                    # If the strand is anti-sense do this
                    elif rows1['strand'] == '-':
                        # Check if the ranges overlap
                        if rows1['start'] < rows2['start'] and rows1['end'] == rows2['end']:
                            # Adjust the end point for rows1 (the exon)
                            df1.at[i, 'end'] == rows2['start'] - 1
                            print(f"Adjusted end for row {i}: {df1.at[i, 'end']}")
                        else:
                            print(f"Ranges do not overlap for row {i}")
                            continue
                    else:
                        continue
                else:
                    continue

            else:
                continue

    return df1

# %%
# # Filter out everything but myotoxin from gxf_df2
# gxf_myo_df = gxf_df2.query("gene_id == 'myotoxin1'")
# gxf_myo_df

# # Seperate 3' UTRs from everthing else
# three_utr_df = gxf_myo_df.query("type2 == 'three_prime_utr'").drop_duplicates() 
# # Seperate 5' UTRs from everthing else
# five_utr_df = gxf_myo_df.query("type2 == 'five_prime_utr'").drop_duplicates()

# # Get 3' and 5' UTRs
# three_five_utr_df = gxf_myo_df.query("type2 == 'three_prime_utr' or type2 == 'five_prime_utr'").drop_duplicates()

# %%
# # Use the function to re-calculate the start or end for the CDS
# three_five_utr_recalc_df = range_recalc(gxf_myo_df, three_five_utr_df)
# # print(type(three_five_utr_recalc_df))

# %%
# three_five_utr_df

# %%
# three_five_utr_recalc_df

# %%
# Create an order for the gene_ids based on their first occurrence
gene_order = gxf_df2['gene_id'].drop_duplicates().reset_index().set_index('gene_id')['index']
print(gene_order)

# Map each row to its gene_id's first occurrence index
row_order = gxf_df2['gene_id'].map(gene_order)

# Sort the data frame using the calculated order
gxf_df3 = gxf_df2.iloc[row_order.argsort(kind='stable')]
gxf_df3
# Out:
# gene_id
# myotoxin1                                                                    1
# maker-scaffold-Z-augustus-gene-0.12_crovir-transcript-1688                   6
# maker-scaffold-Z-augustus-gene-0.8_crovir-transcript-1686                   14
# augustus_masked-scaffold-Z-processed-gene-0.1_crovir-transcript-1684        24
# augustus_masked-scaffold-Z-processed-gene-0.2_crovir-transcript-1685        31
#                                                                          ...
# augustus_masked-scaffold-un6484-processed-gene-0.0                      355120
# augustus_masked-scaffold-un6633-processed-gene-0.0                      355127
# augustus_masked-scaffold-un7034-processed-gene-0.0                      355134
# myotoxin3                                                               355141
# myotoxin2                                                               355147
# Name: index, Length: 18585, dtype: int64
# 10563
#                            seqid source        type     start       end score  \
# 1       PE-reconstructed-10x-myo      .  transcript         1      2076     .
# 2       PE-reconstructed-10x-myo      .        exon         1       746     .
# 3       PE-reconstructed-10x-myo      .        exon      1640      1765     .
# 4       PE-reconstructed-10x-myo      .        exon      1911      2076     .
# 355152  PE-reconstructed-10x-myo      .         NaN         1       689     .
# ...                          ...    ...         ...       ...       ...   ...
# 10625                 scaffold-Z  maker        exon  50089151  50089234     .
# 10626                 scaffold-Z  maker        exon  50091196  50091332     .
# 10627                 scaffold-Z  maker        exon  50098875  50099096     .
# 10628                 scaffold-Z  maker        exon  50108507  50108665     .
# 10629                 scaffold-Z  maker         CDS  50069870  50069902     .
#
#        strand phase                                         attributes  \
# 1           +     .               ID=myotoxin_model_1;geneID=myotoxin1
# 2           +     .                            Parent=myotoxin_model_1
# 3           +     .                            Parent=myotoxin_model_1
# 4           +     .                            Parent=myotoxin_model_1
# 355152      +     .                            Parent=myotoxin_model_1
# ...       ...   ...                                                ...
# 10625       -     .  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
# 10626       -     .  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
# 10627       -     .  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
# 10628       -     .  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
# 10629       -     0  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
#
#                  type2                                        attributes2  \
# 1           transcript  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 2                 exon  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 3                 exon  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 4                 exon  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 355152  five_prime_utr  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# ...                ...                                                ...
# 10625             exon  gene_id "maker-scaffold-Z-augustus-gene-167.13...
# 10626             exon  gene_id "maker-scaffold-Z-augustus-gene-167.13...
# 10627             exon  gene_id "maker-scaffold-Z-augustus-gene-167.13...
# 10628             exon  gene_id "maker-scaffold-Z-augustus-gene-167.13...
# 10629              CDS  gene_id "maker-scaffold-Z-augustus-gene-167.13...
#
#                                                   gene_id
# 1                                               myotoxin1
# 2                                               myotoxin1
# 3                                               myotoxin1
# 4                                               myotoxin1
# 355152                                          myotoxin1
# ...                                                   ...
# 10625   maker-scaffold-Z-augustus-gene-167.13_crovir-t...
# 10626   maker-scaffold-Z-augustus-gene-167.13_crovir-t...
# 10627   maker-scaffold-Z-augustus-gene-167.13_crovir-t...
# 10628   maker-scaffold-Z-augustus-gene-167.13_crovir-t...
# 10629   maker-scaffold-Z-augustus-gene-167.13_crovir-t...
#
# [10563 rows x 12 columns]

# %%
# Create a slice of the rows so that I can check the run in a reasonable amount of time
percent = 3 # percent of rows to be taken from the data

# Calculate the number of rows to be taken
num_rows = int(len(gxf_df3) * (percent / 100))
print(num_rows)

# Take the slice of rows
gxf_df4 = gxf_df3.iloc[:num_rows]
gxf_df4

# %%
# Now that I know it works, I can apply the function to the entire data frame and give it a second data frame that contains both 3' and 5' UTRs
# Seperate three_prime_utr and five_prime_utrs
utrs_df = (
    gxf_df4
        .query("type2 in ['three_prime_utr', 'five_prime_utr']")
        .drop_duplicates()
)
utrs_df
# Out:
#                            seqid source type     start       end score strand  \
# 355152  PE-reconstructed-10x-myo      .  NaN         1       689     .      +
# 355153  PE-reconstructed-10x-myo      .  NaN      1923      2076     .      +
# 355154                scaffold-Z  maker  NaN      5240      5320     .      -
# 355155                scaffold-Z  maker  NaN    195400    195678     .      -
# 355156                scaffold-Z  maker  NaN    399852    400362     .      +
# ...                          ...    ...  ...       ...       ...   ...    ...
# 355639                scaffold-Z  maker  NaN  49814289  49815107     .      +
# 355640                scaffold-Z  maker  NaN  49882494  49885680     .      +
# 355641                scaffold-Z  maker  NaN  49894593  49895219     .      -
# 355642                scaffold-Z  maker  NaN  50028720  50028977     .      -
# 355643                scaffold-Z  maker  NaN  50022044  50022360     .      -
#
#        phase                                         attributes  \
# 355152     .                            Parent=myotoxin_model_1
# 355153     .                            Parent=myotoxin_model_1
# 355154     .  Parent=maker-scaffold-Z-augustus-gene-0.12-mRNA-1
# 355155     .  Parent=maker-scaffold-Z-augustus-gene-0.15-mRNA-1
# 355156     .   Parent=maker-scaffold-Z-augustus-gene-1.4-mRNA-1
# ...      ...                                                ...
# 355639     .  Parent=maker-scaffold-Z-augustus-gene-166.5-mR...
# 355640     .  Parent=maker-scaffold-Z-augustus-gene-166.5-mR...
# 355641     .  Parent=maker-scaffold-Z-augustus-gene-166.6-mR...
# 355642     .  Parent=maker-scaffold-Z-augustus-gene-166.7-mR...
# 355643     .  Parent=maker-scaffold-Z-augustus-gene-166.7-mR...
#
#                   type2                                        attributes2  \
# 355152   five_prime_utr  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 355153  three_prime_utr  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 355154  three_prime_utr  gene_id "maker-scaffold-Z-augustus-gene-0.12_c...
# 355155  three_prime_utr  gene_id "maker-scaffold-Z-augustus-gene-0.15_c...
# 355156  three_prime_utr  gene_id "maker-scaffold-Z-augustus-gene-1.4_cr...
# ...                 ...                                                ...
# 355639   five_prime_utr  gene_id "maker-scaffold-Z-augustus-gene-166.5_...
# 355640  three_prime_utr  gene_id "maker-scaffold-Z-augustus-gene-166.5_...
# 355641  three_prime_utr  gene_id "maker-scaffold-Z-augustus-gene-166.6_...
# 355642   five_prime_utr  gene_id "maker-scaffold-Z-augustus-gene-166.7_...
# 355643  three_prime_utr  gene_id "maker-scaffold-Z-augustus-gene-166.7_...
#
#                                                   gene_id
# 355152                                          myotoxin1
# 355153                                          myotoxin1
# 355154  maker-scaffold-Z-augustus-gene-0.12_crovir-tra...
# 355155  maker-scaffold-Z-augustus-gene-0.15_crovir-tra...
# 355156  maker-scaffold-Z-augustus-gene-1.4_crovir-tran...
# ...                                                   ...
# 355639  maker-scaffold-Z-augustus-gene-166.5_crovir-tr...
# 355640  maker-scaffold-Z-augustus-gene-166.5_crovir-tr...
# 355641  maker-scaffold-Z-augustus-gene-166.6_crovir-tr...
# 355642  maker-scaffold-Z-augustus-gene-166.7_crovir-tr...
# 355643  maker-scaffold-Z-augustus-gene-166.7_crovir-tr...
#
# [707 rows x 12 columns]

# %%
# Apply the function to the main data frame and the above data frame
recscaled_exons_df = range_recalc(gxf_df4, utrs_df)
recscaled_exons_df
# Out:
# Matching seqid found: PE-reconstructed-10x-myo
# Adjusted start for row 2: 690
# Matching seqid found: PE-reconstructed-10x-myo
# Ranges do not overlap for row 2
# Matching seqid found: PE-reconstructed-10x-myo
# Ranges do not overlap for row 3
# Matching seqid found: PE-reconstructed-10x-myo
# Ranges do not overlap for row 3
# Matching seqid found: PE-reconstructed-10x-myo
# Ranges do not overlap for row 4
# Matching seqid found: PE-reconstructed-10x-myo
# Adjusted end for row 4: 1922
# Matching seqid found: scaffold-Z
# Adjusted start for row 7: 5321
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 8
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 9
# Matching seqid found: scaffold-Z
# Adjusted start for row 92: 195679
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 93
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 202
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 203
# Matching seqid found: scaffold-Z
# Adjusted end for row 204: 399851
# Matching seqid found: scaffold-Z
# Adjusted start for row 220: 544345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 220
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 221
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 221
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 222
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 222
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 223
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 223
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 224
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 224
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 225
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 225
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 226
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 226
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 227
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 227
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 228
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 228
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 229
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 229
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 230
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 230
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 231
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 231
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 232
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 232
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 233
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 233
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 234
# Matching seqid found: scaffold-Z
# Adjusted end for row 234: 578616
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 252
# Matching seqid found: scaffold-Z
# Adjusted start for row 252: 603451
# Matching seqid found: scaffold-Z
# Adjusted end for row 253: 605610
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 253
# Matching seqid found: scaffold-Z
# Adjusted start for row 266: 634860
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 267
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 272
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 273
# Matching seqid found: scaffold-Z
# Adjusted end for row 274: 642489
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 280
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 281
# Matching seqid found: scaffold-Z
# Adjusted end for row 282: 661487
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 288
# Matching seqid found: scaffold-Z
# Adjusted start for row 288: 841679
# Matching seqid found: scaffold-Z
# Adjusted end for row 289: 846574
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 289
# Matching seqid found: scaffold-Z
# Adjusted start for row 294: 923022
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 294
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 295
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 295
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 296
# Matching seqid found: scaffold-Z
# Adjusted end for row 296: 925967
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 321
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 322
# Matching seqid found: scaffold-Z
# Adjusted end for row 323: 1099406
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 329
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 329
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 330
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 330
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 331
# Matching seqid found: scaffold-Z
# Adjusted start for row 331: 1108572
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 332
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 332
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 343
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 344
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 345
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 346
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 347
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 348
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 349
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 350
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 351
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 352
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 353
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 354
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 355
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 356
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 357
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 358
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 359
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 360
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 362
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 363
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 364
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 365
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 366
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 367
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 368
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 369
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 370
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 371
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 372
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 373
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 374
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 375
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 376
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 377
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 378
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 379
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 380
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 381
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 382
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 383
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 384
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 385
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 386
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 387
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 388
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 388
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 388
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 388
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 388
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 388
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 388
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 388
# Matching seqid found: scaffold-Z
# ...
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10458
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10459
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10459
# Matching seqid found: scaffold-Z
# Adjusted start for row 10459: 49539138
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10459
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10460
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10460
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10460
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10460
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10461
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10461
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10461
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10461
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10462
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10462
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10462
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10462
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10463
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10463
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10463
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10463
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10464
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10464
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10464
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10464
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10465
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10465
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10465
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10465
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10466
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10466
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10466
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10466
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10467
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10467
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10467
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10467
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10468
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10468
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10468
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10468
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10469
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10469
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10469
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10469
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10470
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10470
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10470
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10470
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10471
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10471
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10471
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10471
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10472
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10472
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10472
# Matching seqid found: scaffold-Z
# Adjusted end for row 10472: 49554658
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10473
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10473
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10473
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10473
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10474
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10474
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10474
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10474
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10491
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10491
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10492
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10492
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10493
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10493
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10494
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10494
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10495
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10495
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10496
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10496
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10497
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10497
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10498
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10498
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10499
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10499
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10500
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10500
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10501
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10501
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10502
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10502
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10503
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10503
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10504
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10504
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10505
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10505
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10506
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10506
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10507
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10507
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10508
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10508
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10509
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10509
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10510
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10510
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10511
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10511
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10512
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10512
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10513
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10513
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10514
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10514
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10515
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10515
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10516
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10516
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10517
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10517
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10518
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10518
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10519
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10519
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10520
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10520
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10521
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10521
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10522
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10522
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10523
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10523
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10524
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10524
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10525
# Matching seqid found: scaffold-Z
# Adjusted end for row 10525: 49714525
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10526
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10526
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10527
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10527
# Matching seqid found: scaffold-Z
# Adjusted start for row 10565: 49815108
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10565
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10566
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10566
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10567
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10567
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10568
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10568
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10569
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10569
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10570
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10570
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10571
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10571
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10572
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10572
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10573
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10573
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10574
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10574
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10575
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10575
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10576
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10576
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10577
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10577
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10578
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10578
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10579
# Matching seqid found: scaffold-Z
# Adjusted end for row 10579: 49882493
# Matching seqid found: scaffold-Z
# Adjusted start for row 10597: 49895220
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10598
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10599
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10605
# Matching seqid found: scaffold-Z
# Adjusted start for row 10605: 50022361
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10606
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10606
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10607
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10607
# Matching seqid found: scaffold-Z
# Adjusted end for row 10608: 50028977
# Matching seqid found: scaffold-Z
# Ranges do not overlap for row 10608
#                            seqid source        type     start       end score  \
# 1       PE-reconstructed-10x-myo      .  transcript         1      2076     .
# 2       PE-reconstructed-10x-myo      .        exon       690       746     .
# 3       PE-reconstructed-10x-myo      .        exon      1640      1765     .
# 4       PE-reconstructed-10x-myo      .        exon      1911      1922     .
# 355152  PE-reconstructed-10x-myo      .         NaN         1       689     .
# ...                          ...    ...         ...       ...       ...   ...
# 10625                 scaffold-Z  maker        exon  50089151  50089234     .
# 10626                 scaffold-Z  maker        exon  50091196  50091332     .
# 10627                 scaffold-Z  maker        exon  50098875  50099096     .
# 10628                 scaffold-Z  maker        exon  50108507  50108665     .
# 10629                 scaffold-Z  maker         CDS  50069870  50069902     .
#
#        strand phase                                         attributes  \
# 1           +     .               ID=myotoxin_model_1;geneID=myotoxin1
# 2           +     .                            Parent=myotoxin_model_1
# 3           +     .                            Parent=myotoxin_model_1
# 4           +     .                            Parent=myotoxin_model_1
# 355152      +     .                            Parent=myotoxin_model_1
# ...       ...   ...                                                ...
# 10625       -     .  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
# 10626       -     .  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
# 10627       -     .  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
# 10628       -     .  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
# 10629       -     0  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
#
#                  type2                                        attributes2  \
# 1           transcript  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 2                 exon  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 3                 exon  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 4                 exon  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# 355152  five_prime_utr  gene_id "myotoxin1"; transcript_id "myotoxin_m...
# ...                ...                                                ...
# 10625             exon  gene_id "maker-scaffold-Z-augustus-gene-167.13...
# 10626             exon  gene_id "maker-scaffold-Z-augustus-gene-167.13...
# 10627             exon  gene_id "maker-scaffold-Z-augustus-gene-167.13...
# 10628             exon  gene_id "maker-scaffold-Z-augustus-gene-167.13...
# 10629              CDS  gene_id "maker-scaffold-Z-augustus-gene-167.13...
#
#                                                   gene_id
# 1                                               myotoxin1
# 2                                               myotoxin1
# 3                                               myotoxin1
# 4                                               myotoxin1
# 355152                                          myotoxin1
# ...                                                   ...
# 10625   maker-scaffold-Z-augustus-gene-167.13_crovir-t...
# 10626   maker-scaffold-Z-augustus-gene-167.13_crovir-t...
# 10627   maker-scaffold-Z-augustus-gene-167.13_crovir-t...
# 10628   maker-scaffold-Z-augustus-gene-167.13_crovir-t...
# 10629   maker-scaffold-Z-augustus-gene-167.13_crovir-t...
#
# [10563 rows x 12 columns]

# %%
# Format the recalcualted CDS data frame
formated_recscaled_exons_df = (
    recscaled_exons_df
        .assign(
            order = row_order,
            type_priority = (recscaled_exons_df['type2'] != 'transcript').astype(int)
        )
        .sort_values(by=['order', 'type_priority'])
        .get(['seqid', 'source', 'type2', 'start', 'end', 'score', 'strand', 'phase', 'attributes']) # Reorder and remove columns
        .rename(columns={'type2': 'type'})
        .reset_index(drop=True)
)
formated_recscaled_exons_df
# Out:
#                           seqid source            type     start       end  \
# 0      PE-reconstructed-10x-myo      .      transcript         1      2076
# 1      PE-reconstructed-10x-myo      .            exon       690       746
# 2      PE-reconstructed-10x-myo      .            exon      1640      1765
# 3      PE-reconstructed-10x-myo      .            exon      1911      1922
# 4      PE-reconstructed-10x-myo      .  five_prime_utr         1       689
# ...                         ...    ...             ...       ...       ...
# 10558                scaffold-Z  maker            exon  50089151  50089234
# 10559                scaffold-Z  maker            exon  50091196  50091332
# 10560                scaffold-Z  maker            exon  50098875  50099096
# 10561                scaffold-Z  maker            exon  50108507  50108665
# 10562                scaffold-Z  maker             CDS  50069870  50069902
#
#       score strand phase                                         attributes
# 0         .      +     .               ID=myotoxin_model_1;geneID=myotoxin1
# 1         .      +     .                            Parent=myotoxin_model_1
# 2         .      +     .                            Parent=myotoxin_model_1
# 3         .      +     .                            Parent=myotoxin_model_1
# 4         .      +     .                            Parent=myotoxin_model_1
# ...     ...    ...   ...                                                ...
# 10558     .      -     .  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
# 10559     .      -     .  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
# 10560     .      -     .  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
# 10561     .      -     .  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
# 10562     .      -     0  Parent=maker-scaffold-Z-augustus-gene-167.13-m...
#
# [10563 rows x 9 columns]

# %%
# Save the new gff file
formated_recscaled_exons_df.to_csv(
    '/home/administrator/Documents/Kaas/Venom_ncRNA_project/Usable_data/Genome_files/Crotalus_viridis_annotation_with_BPP_and_myotoxin_with_three_and_five_prime_utrs_2024.12.18.gff',
    sep = '\t',
    index = False,
    header = False
)
